# %%
import pandas as pd 
import numpy as np

# %%
#load data : CCTV 데이터

# %%
CCTV_Seoul=pd.read_csv("~/Desktop/data/CCTV_in_Seoul.csv")

# %%
CCTV_Seoul.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
CCTV_Seoul.columns
# Out:
# Index(['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
CCTV_Seoul.rename(columns={CCTV_Seoul.columns[0]:'구별'},inplace=True)

# %%
CCTV_Seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
def grows(x):
    return (x[3]+x[4]+x[5])/x[2]*100

# %%
CCTV_Seoul['최근증가율']=CCTV_Seoul.apply(grows,axis=1)

# %%
CCTV_Seoul.head().sort_values(by='최근증가율', ascending=False)
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 1  강동구  1010        379     99    155    377  166.490765
# 0  강남구  3238       1292    430    584    932  150.619195
# 4  관악구  2109        846    260    390    613  149.290780
# 3  강서구   911        388    258    184     81  134.793814
# 2  강북구   831        369    120    138    204  125.203252

# %%
# load data : 서울시 인구

# %%
pop_Seoul=pd.read_excel("/Users/hanabel/Desktop/data/population_in_Seoul.xls",encoding='utf-8')

# %%
pop_Seoul.head()
# Out:
#          기간  자치구       세대        인구     인구.1     인구.2     인구.3     인구.4  \
# 0        기간  자치구       세대        합계       합계       합계      한국인      한국인
# 1        기간  자치구       세대         계       남자       여자        계       남자
# 2  2017.3/4   합계  4219001  10158411  4975437  5182974  9891448  4849195
# 3  2017.3/4  종로구    73668    164640    80173    84467   155109    76155
# 4  2017.3/4   중구    60130    134174    66064    68110   125332    62011
#
#       인구.5    인구.6    인구.7    인구.8  세대당인구  65세이상고령자
# 0      한국인   등록외국인   등록외국인   등록외국인  세대당인구  65세이상고령자
# 1       여자       계      남자      여자  세대당인구  65세이상고령자
# 2  5042253  266963  126242  140721   2.34   1353486
# 3    78954    9531    4018    5513   2.11     26034
# 4    63321    8842    4053    4789   2.08     21249

# %%
pop_Seoul=pd.read_excel("/Users/hanabel/Desktop/data/population_in_Seoul.xls",
                        encoding='utf-8',
                        header=2, 
                        usecols='B,D,G,J,N'
                       )

# %%
pop_Seoul.head()
# Out:
#    자치구           계        계.1       계.2   65세이상고령자
# 0   합계  10158411.0  9891448.0  266963.0  1353486.0
# 1  종로구    164640.0   155109.0    9531.0    26034.0
# 2   중구    134174.0   125332.0    8842.0    21249.0
# 3  용산구    243922.0   228960.0   14962.0    36727.0
# 4  성동구    312933.0   304879.0    8054.0    40902.0

# %%
pop_Seoul.rename(columns={pop_Seoul.columns[0]:'구별',
                             pop_Seoul.columns[1]:'인구수',
                             pop_Seoul.columns[2]:'한국인',
                             pop_Seoul.columns[3]:'외국인',
                             pop_Seoul.columns[4]:'고령자'
                             },inplace=True)

# %%
pop_Seoul.head()
# Out:
#     구별         인구수        한국인       외국인        고령자
# 0   합계  10158411.0  9891448.0  266963.0  1353486.0
# 1  종로구    164640.0   155109.0    9531.0    26034.0
# 2   중구    134174.0   125332.0    8842.0    21249.0
# 3  용산구    243922.0   228960.0   14962.0    36727.0
# 4  성동구    312933.0   304879.0    8054.0    40902.0

# %%
## CCTV & 인구데이터

# %%
CCTV_Seoul.sort_values(by='소계',ascending=False)
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 0    강남구  3238       1292    430    584    932  150.619195
# 18   양천구  2482       1843    142     30    467   34.671731
# 14   서초구  2297       1406    157    336    398   63.371266
# 4    관악구  2109        846    260    390    613  149.290780
# 21   은평구  2108       1138    224    278    468   85.237258
# 20   용산구  2096       1368    218    112    398   53.216374
# 6    구로구  1884       1142    173    246    323   64.973730
# 10  동대문구  1870       1070     23    198    579   74.766355
# 16   성북구  1651       1009     78    360    204   63.627354
# 22   종로구  1619        464    314    211    630  248.922414
# 8    노원구  1566        542     57    451    516  188.929889
# 7    금천구  1348        674     51    269    354  100.000000
# 15   성동구  1327        730     91    241    265   81.780822
# 11   동작구  1302        544    341    103    314  139.338235
# 19  영등포구  1277        495    214    195    373  157.979798
# ...

# %%
pop_Seoul.head(5)
# Out:
#     구별         인구수        한국인       외국인        고령자
# 0   합계  10158411.0  9891448.0  266963.0  1353486.0
# 1  종로구    164640.0   155109.0    9531.0    26034.0
# 2   중구    134174.0   125332.0    8842.0    21249.0
# 3  용산구    243922.0   228960.0   14962.0    36727.0
# 4  성동구    312933.0   304879.0    8054.0    40902.0

# %%
pop_Seoul.drop([0],inplace=True)

# %%
pop_Seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자
# 1  종로구  164640.0  155109.0   9531.0  26034.0
# 2   중구  134174.0  125332.0   8842.0  21249.0
# 3  용산구  243922.0  228960.0  14962.0  36727.0
# 4  성동구  312933.0  304879.0   8054.0  40902.0
# 5  광진구  372414.0  357743.0  14671.0  43579.0

# %%
pop_Seoul['구별'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구', nan],
#       dtype=object)

# %%
# 몇번째 열에 null이 있는지 보여줌 
pop_Seoul['구별'].isnull()
# Out:
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# Name: 구별, dtype: bool

# %%
# null 열을 return
pop_Seoul[pop_Seoul['구별'].isnull()]
# Out:
#      구별  인구수  한국인  외국인  고령자
# 26  NaN  NaN  NaN  NaN  NaN

# %%
pop_Seoul.drop([26],inplace=True)

# %%
pop_Seoul['구별'].isnull()
# Out:
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# Name: 구별, dtype: bool

# %%
pop_Seoul.columns
# Out:
# Index(['구별', '인구수', '한국인', '외국인', '고령자'], dtype='object')

# %%
# 비율 숫자 넣기 
pop_Seoul['한국인비율']=pop_Seoul['한국인']/pop_Seoul['인구수']*100
pop_Seoul['외국인비율']=pop_Seoul['외국인']/pop_Seoul['인구수']*100
pop_Seoul['고령자비율']=pop_Seoul['고령자']/pop_Seoul['인구수']*100

# %% [markdown]
# pop_Seoul.head()

# %%
pop_Seoul.sort_values(by='외국인', ascending=False).head(5)
# Out:
#       구별       인구수       한국인      외국인      고령자     외국인비율      한국인비율      고령자비율
# 19  영등포구  401908.0  368818.0  33090.0  53620.0  8.233228  91.766772  13.341362
# 17   구로구  443288.0  412972.0  30316.0  58260.0  6.838895  93.161105  13.142697
# 18   금천구  253646.0  235608.0  18038.0  33818.0  7.111486  92.888514  13.332755
# 21   관악구  522849.0  505188.0  17661.0  69486.0  3.377839  96.622161  13.289879
# 6   동대문구  367769.0  352011.0  15758.0  55287.0  4.284755  95.715245  15.033078

# %%
pop_Seoul.sort_values(by='고령자', ascending=False).head(5)
# Out:
#      구별       인구수       한국인      외국인      고령자     외국인비율      한국인비율      고령자비율
# 24  송파구  668366.0  661750.0   6616.0  75301.0  0.989877  99.010123  11.266432
# 16  강서구  607877.0  601391.0   6486.0  75046.0  1.066992  98.933008  12.345590
# 12  은평구  491899.0  487507.0   4392.0  73850.0  0.892866  99.107134  15.013245
# 11  노원구  562278.0  558432.0   3846.0  73588.0  0.684003  99.315997  13.087476
# 21  관악구  522849.0  505188.0  17661.0  69486.0  3.377839  96.622161  13.289879

# %% [markdown]
# # CCTV데이터와 인구데이터 붙여보기

# %%
data_result=pd.merge(CCTV_Seoul,pop_Seoul,on='구별')

# %%
data_result.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율       인구수       한국인  \
# 0  강남구  3238       1292    430    584    932  150.619195  565731.0  560827.0
# 1  강동구  1010        379     99    155    377  166.490765  446760.0  442654.0
# 2  강북구   831        369    120    138    204  125.203252  329042.0  325552.0
# 3  강서구   911        388    258    184     81  134.793814  607877.0  601391.0
# 4  관악구  2109        846    260    390    613  149.290780  522849.0  505188.0
#
#        외국인      고령자     외국인비율      한국인비율      고령자비율
# 0   4904.0  64579.0  0.866843  99.133157  11.415143
# 1   4106.0  55902.0  0.919062  99.080938  12.512759
# 2   3490.0  56078.0  1.060655  98.939345  17.042809
# 3   6486.0  75046.0  1.066992  98.933008  12.345590
# 4  17661.0  69486.0  3.377839  96.622161  13.289879

# %%
del data_result['2013년도 이전']
del data_result['2014년']
del data_result['2015년']
del data_result['2016년']

# %%
data_result.head()
# Out:
#     구별    소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 0  강남구  3238  150.619195  565731.0  560827.0   4904.0  64579.0  0.866843
# 1  강동구  1010  166.490765  446760.0  442654.0   4106.0  55902.0  0.919062
# 2  강북구   831  125.203252  329042.0  325552.0   3490.0  56078.0  1.060655
# 3  강서구   911  134.793814  607877.0  601391.0   6486.0  75046.0  1.066992
# 4  관악구  2109  149.290780  522849.0  505188.0  17661.0  69486.0  3.377839
#
#        한국인비율      고령자비율
# 0  99.133157  11.415143
# 1  99.080938  12.512759
# 2  98.939345  17.042809
# 3  98.933008  12.345590
# 4  96.622161  13.289879

# %%
data_result.set_index('구별',inplace=True)

# %%
data_result.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  3238  150.619195  565731.0  560827.0   4904.0  64579.0  0.866843
# 강동구  1010  166.490765  446760.0  442654.0   4106.0  55902.0  0.919062
# 강북구   831  125.203252  329042.0  325552.0   3490.0  56078.0  1.060655
# 강서구   911  134.793814  607877.0  601391.0   6486.0  75046.0  1.066992
# 관악구  2109  149.290780  522849.0  505188.0  17661.0  69486.0  3.377839
#
#          한국인비율      고령자비율
# 구별
# 강남구  99.133157  11.415143
# 강동구  99.080938  12.512759
# 강북구  98.939345  17.042809
# 강서구  98.933008  12.345590
# 관악구  96.622161  13.289879

# %%
np.corrcoef(data_result['고령자비율'],data_result['소계'])
# Out:
# array([[ 1.        , -0.26753359],
#        [-0.26753359,  1.        ]])

# %%
data_result.rename(columns={data_result.columns[0]:'CCTV수'
                        , data_result.columns[1]:'최근증가율'},inplace=True)

# %%
data_result.head()
# Out:
#      CCTV수       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구   3238  150.619195  565731.0  560827.0   4904.0  64579.0  0.866843
# 강동구   1010  166.490765  446760.0  442654.0   4106.0  55902.0  0.919062
# 강북구    831  125.203252  329042.0  325552.0   3490.0  56078.0  1.060655
# 강서구    911  134.793814  607877.0  601391.0   6486.0  75046.0  1.066992
# 관악구   2109  149.290780  522849.0  505188.0  17661.0  69486.0  3.377839
#
#          한국인비율      고령자비율
# 구별
# 강남구  99.133157  11.415143
# 강동구  99.080938  12.512759
# 강북구  98.939345  17.042809
# 강서구  98.933008  12.345590
# 관악구  96.622161  13.289879

# %%
data_result.corr()
# Out:
#           CCTV수     최근증가율       인구수       한국인       외국인       고령자     외국인비율  \
# CCTV수  1.000000 -0.264378  0.236036  0.231286  0.031337  0.166187 -0.047289
# 최근증가율 -0.264378  1.000000 -0.094218 -0.083570 -0.156731 -0.071252 -0.045236
# 인구수    0.236036 -0.094218  1.000000  0.998210 -0.169354  0.935802 -0.608254
# 한국인    0.231286 -0.083570  0.998210  1.000000 -0.227996  0.934919 -0.651584
# 외국인    0.031337 -0.156731 -0.169354 -0.227996  1.000000 -0.171546  0.834964
# 고령자    0.166187 -0.071252  0.935802  0.934919 -0.171546  1.000000 -0.622773
# 외국인비율 -0.047289 -0.045236 -0.608254 -0.651584  0.834964 -0.622773  1.000000
# 한국인비율  0.047289  0.045236  0.608254  0.651584 -0.834964  0.622773 -1.000000
# 고령자비율 -0.267534  0.185321 -0.650232 -0.641926 -0.007582 -0.362788  0.265416
#
#           한국인비율     고령자비율
# CCTV수  0.047289 -0.267534
# 최근증가율  0.045236  0.185321
# 인구수    0.608254 -0.650232
# 한국인    0.651584 -0.641926
# 외국인   -0.834964 -0.007582
# 고령자    0.622773 -0.362788
# ...

# %% [markdown]
# # 시각화

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import platform

from matplotlib import font_manager, rc 
plt.rcParams['axes.unicode_minus']=False
rc('font',family='AppleGothic')

# %%
data_result.head()
# Out:
#      CCTV수       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구   3238  150.619195  565731.0  560827.0   4904.0  64579.0  0.866843
# 강동구   1010  166.490765  446760.0  442654.0   4106.0  55902.0  0.919062
# 강북구    831  125.203252  329042.0  325552.0   3490.0  56078.0  1.060655
# 강서구    911  134.793814  607877.0  601391.0   6486.0  75046.0  1.066992
# 관악구   2109  149.290780  522849.0  505188.0  17661.0  69486.0  3.377839
#
#          한국인비율      고령자비율
# 구별
# 강남구  99.133157  11.415143
# 강동구  99.080938  12.512759
# 강북구  98.939345  17.042809
# 강서구  98.933008  12.345590
# 관악구  96.622161  13.289879

# %%
data_result['CCTV수'].plot(kind='barh',grid=True, figsize=(10,6))
plt.show()

# %%
data_result['CCTV수'].sort_values().plot(kind='barh',grid=True, figsize=(10,6))
plt.show()

# %%
data_result['CCTV비율']=data_result['CCTV수']/data_result['인구수']*100
data_result['CCTV비율'].sort_values().plot(kind='barh',grid=True,figsize=(6,6))

# %%
plt.figure(figsize=(6,6))
plt.scatter(data_result['인구수'],data_result['CCTV수'], s=50)
plt.xlabel('인구수')
plt.ylabel('CCTV수')
plt.grid
plt.show()

# %%
fd1=np.polyfit(data_result['인구수'],data_result['CCTV수'],1)
fd1
# Out:
# array([1.12481497e-03, 1.05826669e+03])

# %%
f1=np.poly1d(fd1)
fx=np.linspace(100000,700000,100)

# %%
plt.figure(figsize=(6,6))
plt.scatter(data_result["인구수"], data_result["CCTV수"], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=1, color='g')
plt.xlabel("인구수")
plt.ylabel("CCTV수")
plt.grid()
plt.show()

# %%
data_result['오차']=np.abs(data_result['CCTV수']-f1(data_result['인구수']))
df_sort=data_result.sort_values(by='오차',ascending=False)
df_sort.head()
# Out:
#      CCTV수       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구   3238  150.619195  565731.0  560827.0   4904.0  64579.0  0.866843
# 양천구   2482   34.671731  476627.0  472730.0   3897.0  54598.0  0.817620
# 강서구    911  134.793814  607877.0  601391.0   6486.0  75046.0  1.066992
# 용산구   2096   53.216374  243922.0  228960.0  14962.0  36727.0  6.133928
# 서초구   2297   63.371266  447177.0  442833.0   4344.0  52738.0  0.971427
#
#          한국인비율      고령자비율    CCTV비율           오차
# 구별
# 강남구  99.133157  11.415143  0.572357  1543.390613
# 양천구  99.182380  11.455079  0.520743   887.616126
# 강서구  98.933008  12.345590  0.149866   831.015839
# 용산구  93.866072  15.056862  0.859291   763.366194
# 서초구  99.028573  11.793540  0.513667   735.741927

# %%
plt.figure(figsize=(6,6))
plt.scatter(df_sort['인구수'], df_sort['CCTV수'],
           c=df_sort['오차'], s=50)
plt.plot(fx,f1(fx),line='dashed',lw=3,color='g')

for n in range(10):
    plt.text(df_sort['인구수'][n]*1.02, df_sort['CCTV수'][n]*0.98,
            df_sort.index[n], font_size=15)

plt.xlabel('인구수')
plt.ylabel('인구당비율')

plt.colorbar()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-1c26968112fb> in <module>()
#       2 plt.scatter(df_sort['인구수'], df_sort['CCTV수'],
#       3            c=df_sort['오차'], s=50)
# ----> 4 plt.plot(fx,f1(fx),line='dashed',lw=3,color='g')
#       5
#       6 for n in range(10):
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
# ...
